# %%
import pandas as pd
data=pd.read_excel('Book1.xlsx',sheet_name='Sheet1')

# %%
data.head()
# Out:
#        SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0   20MICRONS     EQ     29.15     29.40     28.50     28.60     28.50
# 1  21STCENMGM     EQ     10.05     10.45     10.05     10.40     10.45
# 2  3IINFOTECH     EQ      2.45      2.50      2.35      2.40      2.40
# 3     3MINDIA     EQ  21301.00  21489.70  20971.30  21078.00  21100.05
# 4      5PAISA     EQ    344.15    344.15    344.15    344.15    344.15
#
#    PREVCLOSE  TOTTRDQTY    TOTTRDVAL  TIMESTAMP  TOTALTRADES          ISIN
# 0      29.15      49903   1429604.60 2020-07-31          774  INE144J01027
# 1      10.25       8380     85549.20 2020-07-31           68  INE253B01015
# 2       2.45    2759633   6644268.10 2020-07-31         1440  INE748C01020
# 3   21197.45       2040  43098707.35 2020-07-31          964  INE470A01017
# 4     362.25       9336   3212984.40 2020-07-31          127  INE618L01018

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1932 entries, 0 to 1931
# Data columns (total 13 columns):
# SYMBOL         1932 non-null object
# SERIES         1926 non-null object
# OPEN           1932 non-null float64
# HIGH           1932 non-null float64
# LOW            1932 non-null float64
# CLOSE          1932 non-null float64
# LAST           1932 non-null float64
# PREVCLOSE      1932 non-null float64
# TOTTRDQTY      1932 non-null int64
# TOTTRDVAL      1932 non-null float64
# TIMESTAMP      1932 non-null datetime64[ns]
# TOTALTRADES    1932 non-null int64
# ISIN           1932 non-null object
# dtypes: datetime64[ns](1), float64(7), int64(2), object(3)
# memory usage: 173.6+ KB

# %%
data.shape
# Out:
# (1932, 13)

# %%
data1=pd.read_excel('Book1.xlsx',sheet_name=['Sheet1','Sheet2'])

# %%
data1
# Out:
# OrderedDict([('Sheet1',
#                         SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
#               0      20MICRONS     EQ     29.15     29.40     28.50     28.60     28.50
#               1     21STCENMGM     EQ     10.05     10.45     10.05     10.40     10.45
#               2     3IINFOTECH     EQ      2.45      2.50      2.35      2.40      2.40
#               3        3MINDIA     EQ  21301.00  21489.70  20971.30  21078.00  21100.05
#               4         5PAISA     EQ    344.15    344.15    344.15    344.15    344.15
#               5        63MOONS     BE     69.30     70.85     69.00     70.05     70.40
#               6      716GS2050     GS    108.00    111.00    106.30    111.00    111.00
#               7      757GS2033     GS    116.00    116.00    116.00    116.00    116.00
#               8       A2ZINFRA     EQ      4.20      4.20      3.95      4.00      4.00
# ...

# %%
data2=pd.read_excel('Book1.xlsx',sheet_name=None)

# %%
print(data2)
# Out:
# OrderedDict([('Sheet1',           SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0      20MICRONS     EQ     29.15     29.40     28.50     28.60     28.50
# 1     21STCENMGM     EQ     10.05     10.45     10.05     10.40     10.45
# 2     3IINFOTECH     EQ      2.45      2.50      2.35      2.40      2.40
# 3        3MINDIA     EQ  21301.00  21489.70  20971.30  21078.00  21100.05
# 4         5PAISA     EQ    344.15    344.15    344.15    344.15    344.15
# 5        63MOONS     BE     69.30     70.85     69.00     70.05     70.40
# 6      716GS2050     GS    108.00    111.00    106.30    111.00    111.00
# 7      757GS2033     GS    116.00    116.00    116.00    116.00    116.00
# 8       A2ZINFRA     EQ      4.20      4.20      3.95      4.00      4.00
# 9          AARON     SM     43.35     43.35     43.35     43.35     43.35
# 10    AARTIDRUGS     EQ   1710.00   1750.00   1710.00   1740.25   1735.00
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-9f71d6cf109f> in <module>()
# ----> 1 data2.shape
#
# AttributeError: 'collections.OrderedDict' object has no attribute 'shape'
